# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the Dataset

# %%
dataset = pd.read_csv("Data.csv")

# %%
dataset
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %% [markdown]
# ## Taking care of Missing data

# %%
dataset['Age'] = dataset['Age'].fillna(dataset['Age'].mean())
dataset['Salary'] = dataset['Salary'].fillna(dataset['Salary'].mean())

# %%
dataset
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4  Germany  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %% [markdown]
# ## Encoding Categorical data

# %%
dataset = pd.get_dummies(dataset,columns = ["Country"])
dataset = dataset.replace({'Purchased' : {'Yes' : 1 , 'No' : 0}})

# %%
dataset
# Out:
#          Age        Salary  Purchased  Country_France  Country_Germany  \
# 0  44.000000  72000.000000          0               1                0
# 1  27.000000  48000.000000          1               0                0
# 2  30.000000  54000.000000          0               0                1
# 3  38.000000  61000.000000          0               0                0
# 4  40.000000  63777.777778          1               0                1
# 5  35.000000  58000.000000          1               1                0
# 6  38.777778  52000.000000          0               0                0
# 7  48.000000  79000.000000          1               1                0
# 8  50.000000  83000.000000          0               0                1
# 9  37.000000  67000.000000          1               1                0
#
#    Country_Spain
# 0              0
# 1              1
# 2              0
# 3              1
# 4              0
# 5              0
# 6              1
# 7              0
# 8              0
# 9              0

# %%
x = dataset.drop('Purchased',axis = 1)

# %%
x
# Out:
#          Age        Salary  Country_France  Country_Germany  Country_Spain
# 0  44.000000  72000.000000               1                0              0
# 1  27.000000  48000.000000               0                0              1
# 2  30.000000  54000.000000               0                1              0
# 3  38.000000  61000.000000               0                0              1
# 4  40.000000  63777.777778               0                1              0
# 5  35.000000  58000.000000               1                0              0
# 6  38.777778  52000.000000               0                0              1
# 7  48.000000  79000.000000               1                0              0
# 8  50.000000  83000.000000               0                1              0
# 9  37.000000  67000.000000               1                0              0

# %%
y = dataset['Purchased']

# %%
y
# Out:
# 0    0
# 1    1
# 2    0
# 3    0
# 4    1
# 5    1
# 6    0
# 7    1
# 8    0
# 9    1
# Name: Purchased, dtype: int64

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size = 0.2,random_state = 1)

# %%
x_train
# Out:
#          Age        Salary  Country_France  Country_Germany  Country_Spain
# 6  38.777778  52000.000000               0                0              1
# 4  40.000000  63777.777778               0                1              0
# 0  44.000000  72000.000000               1                0              0
# 3  38.000000  61000.000000               0                0              1
# 1  27.000000  48000.000000               0                0              1
# 7  48.000000  79000.000000               1                0              0
# 8  50.000000  83000.000000               0                1              0
# 5  35.000000  58000.000000               1                0              0

# %%
y_train
# Out:
# 6    0
# 4    1
# 0    0
# 3    0
# 1    1
# 7    1
# 8    0
# 5    1
# Name: Purchased, dtype: int64

# %%
x_test
# Out:
#     Age   Salary  Country_France  Country_Germany  Country_Spain
# 2  30.0  54000.0               0                1              0
# 9  37.0  67000.0               1                0              0

# %%
y_test
# Out:
# 2    0
# 9    1
# Name: Purchased, dtype: int64

# %% [markdown]
# ## Feature Scaling

# %%
x_train = (x_train-np.mean(x_train))/np.std(x_train)
x_test = (x_test-np.mean(x_test))/np.std(x_test)

# %%
x_train
# Out:
#         Age    Salary  Country_France  Country_Germany  Country_Spain
# 6 -0.191592 -1.078126       -0.774597        -0.577350       1.290994
# 4 -0.014117 -0.070132       -0.774597         1.732051      -0.774597
# 0  0.566709  0.633562        1.290994        -0.577350      -0.774597
# 3 -0.304530 -0.307866       -0.774597        -0.577350       1.290994
# 1 -1.901801 -1.420464       -0.774597        -0.577350       1.290994
# 7  1.147534  1.232653        1.290994        -0.577350      -0.774597
# 8  1.437947  1.574991       -0.774597         1.732051      -0.774597
# 5 -0.740150 -0.564619        1.290994        -0.577350      -0.774597

# %%
x_test
# Out:
#    Age  Salary  Country_France  Country_Germany  Country_Spain
# 2 -1.0    -1.0            -1.0              1.0            NaN
# 9  1.0     1.0             1.0             -1.0            NaN
